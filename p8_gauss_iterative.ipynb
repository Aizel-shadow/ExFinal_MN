# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np

def resolver_sistema(A, b):

    sol = np.linalg.solve(A, b)

    m = -A[1, 0] / A[1, 1]
    return sol, m

# %% [markdown]
# # Ejercicio 1

# %%
# %autoreload 2
from src import gauss_jacobi, gauss_seidel
A1 = np.array([[2, 1], [3, 2]])
b1 = np.array([5, 8])
sol1, m1 = resolver_sistema(A1, b1)
print(f" x={sol1[0]}, y={sol1[1]}, m={m1}")
# Out:
#  x=2.0000000000000004, y=0.9999999999999993, m=-1.5

# %% [markdown]
# # Ejercicio 2

# %%
# %autoreload 2
from src import gauss_jacobi, gauss_seidel
A2 = np.array([[1, 1], [-2, 1]])
b2 = np.array([6, 0])
print(f" x={sol2[0]}, y={sol2[1]}, m={m2}")
# Out:
#  x=2.0, y=4.0, m=2.0

# %% [markdown]
# # Código para dibujar

# %%
import matplotlib.pyplot as plt

# Extraer valores de la trayectoria
# -- Datos de ejemplo --
x_values = [0, 6, 2, 2] 
y_values = [0, 12, 4, 4] 

plt.figure(figsize=(8, 6))


plt.plot(x_values, y_values, "o--", color="blue", markersize=4, label="iteraciones")


plt.plot(x_values[0], y_values[0], "gd", markersize=10, label="inicio $X_0$")
plt.plot(x_values[-1], y_values[-1], "ro", markersize=10, label="solución $X_{sol}$")

plt.xlabel("variable x")
plt.ylabel("variable y")
plt.title("trayectoria de convergencia")
plt.axhline(0, color='black',linewidth=0.5)
plt.axvline(0, color='black',linewidth=0.5)
plt.grid(True, linestyle=':', alpha=0.6)
plt.legend()

plt.show()
